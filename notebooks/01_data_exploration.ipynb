# %% [markdown]
# # NS8 Data Exploration
#
# Quick sanity checks for Phase 1 datasets. Extend with plots and deeper checks as features evolve.

# %%
from ns8lab.data import build_dataset

df = build_dataset(task="task_a_view", n_samples=5, seed=0)
df.head()
